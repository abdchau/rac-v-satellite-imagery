# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from tqdm import tqdm_notebook as tqdm
import tensorflow as tf
import tensorflow.keras as K
import importlib
import tifffile as tiff
import pandas as pd
tf.enable_eager_execution()

# %%
import dataPreparation
import unetModelFunc

importlib.reload(dataPreparation)
importlib.reload(unetModelFunc)
#import functions
from dataPreparation import *
from unetModelFunc import *

# %%
#writeMasks()

# %%
y = readMasks()

# %%
a=tiff.imread('./Data/three_band/6140_1_2.tif')

# %%
tiff.imshow(a)
# Out:
# (<Figure size 988.8x604.8 with 1 Axes>,
# ...
#  <matplotlib.image.AxesImage at 0x7fb1c4b242b0>)

# %%
b=np.load("./Data/Masks/6140_1_2.npy")

# %%
b[3].shape
# Out:
# (3396, 3348)

# %%
plt.imshow(b[3], cmap=plt.cm.binary)

# %%
model = UNetModel(shape=(112,112,1), origDepth=16)

# %%
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_5 (InputLayer)            [(None, 112, 112, 1) 0
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 112, 112, 16) 160         input_5[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 112, 112, 16) 2320        conv2d_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 112, 112, 16) 64          conv2d_77[0][0]
# __________________________________________________________________________________________________
# ...

# %%
plt.imshow(y[5,4], cmap=plt.cm.binary)

# %%
len(y)
# Out:
# 25

# %%
np.sum(y[18][9])

# %%
imageId = "6140_1_2"

img_names = get_image_names(imageId)
#images = dict()

#for k in img_names.keys():
images = tiff.imread(img_names['3'])
print(images.shape)
# Out:
# (3, 3348, 3396)

# %%
tiff.imshow(images['P'])

# %%
X = get_images()

# %%
X[1].shape
# Out:
# (3, 3345, 3396)

# %%
model.to_json()
